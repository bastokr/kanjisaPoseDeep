# %%
from google.colab import drive

drive.mount('/content/gdrive')

# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (8.0.128)
# Requirement already satisfied: matplotlib>=3.2.2 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from ultralytics) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from ultralytics) (9.3.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from ultralytics) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from ultralytics) (2.28.1)
# Requirement already satisfied: scipy>=1.4.1 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from ultralytics) (1.11.0)
# Requirement already satisfied: torch>=1.7.0 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from ultralytics) (2.1.0.dev20230523+cu117)
# Requirement already satisfied: torchvision>=0.8.1 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from ultralytics) (0.16.0.dev20230523+cu117)
# Requirement already satisfied: tqdm>=4.64.0 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: pandas>=1.1.4 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: seaborn>=0.11.0 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: psutil in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from matplotlib>=3.2.2->ultralytics) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from matplotlib>=3.2.2->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from matplotlib>=3.2.2->ultralytics) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from matplotlib>=3.2.2->ultralytics) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from matplotlib>=3.2.2->ultralytics) (1.24.1)
# Requirement already satisfied: packaging>=20.0 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from matplotlib>=3.2.2->ultralytics) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from matplotlib>=3.2.2->ultralytics) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from matplotlib>=3.2.2->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2022.12.7)
# Requirement already satisfied: filelock in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from torch>=1.7.0->ultralytics) (3.9.0)
# Requirement already satisfied: typing-extensions in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from torch>=1.7.0->ultralytics) (4.7.1)
# Requirement already satisfied: sympy in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from torch>=1.7.0->ultralytics) (1.11.1)
# Requirement already satisfied: networkx in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from torch>=1.7.0->ultralytics) (3.0rc1)
# Requirement already satisfied: jinja2 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from torch>=1.7.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from torch>=1.7.0->ultralytics) (2023.4.0)
# Requirement already satisfied: pytorch-triton==2.1.0+7d1a95b046 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from torch>=1.7.0->ultralytics) (2.1.0+7d1a95b046)
# Requirement already satisfied: six>=1.5 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from jinja2->torch>=1.7.0->ultralytics) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/skpark/.conda/envs/mmlab/lib/python3.11/site-packages (from sympy->torch>=1.7.0->ultralytics) (1.2.1)

# %%
# !ls '/content/gdrive/My Drive/'

# %%
import os 


model = YOLO('yolov8n-pose.pt')  # load a pretrained model (recommended for training)

model.train(data='/home/skpark/git/pose-detection-keypoints-estimation-yolov8/config.yaml', epochs=1, imgsz=640)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 import os
# ----> 4 model = YOLO('yolov8n-pose.pt')  # load a pretrained model (recommended for training)
#       6 model.train(data='/home/skpark/git/pose-detection-keypoints-estimation-yolov8/config.yaml', epochs=1, imgsz=640)
#
# NameError: name 'YOLO' is not defined

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/ComputerVisionEngineer/PoseDetectionYolov8'
# Out:
# cp: cannot stat '/content/runs': No such file or directory
